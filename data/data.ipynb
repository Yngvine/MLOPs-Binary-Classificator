# %%
import sys
import pandas as pd
from pathlib import Path

# Add project root to path
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# Import from lib (where we made the changes)
from custom_lib.data import (
    load_data,
    create_imbalanced_dataset,
    plot_class_distribution,
    plot_violin_per_feature,
    plot_correlation_heatmap,
    plot_boxplot_comparison,
    plot_pairplot_sample
)

# %%
# Load Data
df = load_data()
print(f"Loaded dataset with {len(df)} samples")
# Out:
# Loaded dataset with 18185 samples

# %%
# Create Imbalanced Dataset
# Downsampling 'Osmancik' (Class 1) to create imbalance
df_imbalanced = create_imbalanced_dataset(
    df=df,
    target_class=0,
    keep_percentage=10,
    output_filename="riceClassification_imbalanced.csv"
)
# Out:
# Created imbalanced dataset: c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\data\umbalanced\riceClassification_imbalanced.csv
#
# Original distribution:
#   Class 0 (Gonen): 8,200
#   Class 1 (Jasmine): 9,985
#
# New distribution:
#   Class 0 (Gonen): 820 (7.6%)
#   Class 1 (Jasmine): 9,985 (92.4%)
#
# Imbalance ratio: 12.18:1

# %%
# 1. Class Distribution
plot_class_distribution(df_imbalanced)
# Out:
# c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\custom_lib\data.py:237: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(

# %%
# 2. Feature Distributions (Violin Plots)
plot_violin_per_feature(df_imbalanced)
# Out:
# c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\custom_lib\data.py:137: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([CLASS_LABELS.get(cast(int, i), str(i)) for i in sorted(df["Class"].unique())])
# c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\custom_lib\data.py:137: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([CLASS_LABELS.get(cast(int, i), str(i)) for i in sorted(df["Class"].unique())])
# c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\custom_lib\data.py:137: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([CLASS_LABELS.get(cast(int, i), str(i)) for i in sorted(df["Class"].unique())])
# ...

# %%
# 3. Correlation Heatmap
plot_correlation_heatmap(df_imbalanced)

# %%
# 4. Boxplot Comparison
plot_boxplot_comparison(df_imbalanced)
# Out:
# c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\custom_lib\data.py:375: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([CLASS_LABELS.get(cast(int, i), str(i)) for i in sorted(df["Class"].unique())])
# c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\custom_lib\data.py:375: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([CLASS_LABELS.get(cast(int, i), str(i)) for i in sorted(df["Class"].unique())])
# c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\custom_lib\data.py:375: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([CLASS_LABELS.get(cast(int, i), str(i)) for i in sorted(df["Class"].unique())])
# ...

# %%
# 5. Pairplot Sample
plot_pairplot_sample(df_imbalanced, sample_size=500)
# Out:
# c:\Users\ivons\Downloads\MLOPs-Binary-Classificator\custom_lib\data.py:304: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled = df.groupby("Class", group_keys=False).apply(
